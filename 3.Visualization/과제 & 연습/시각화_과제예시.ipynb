# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_excel("../dataSet/auto-mpg.xlsx")
df1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
sns.relplot(data = df1, x = 'weight', y = 'mpg', hue = "origin", palette=['skyblue', 'limegreen', 'red'])

# %%
fig, ax = plt.subplots()
for key, grp in df1.groupby(['origin']):
    ax.scatter(x='weight', y='mpg', data=grp, label=key)

ax.legend()
plt.show()

# %%
sns.scatterplot(data = df1,x = "displacement",y = "mpg")
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='mpg'>

# %%
df1[["displacement","mpg"]].plot(kind = "scatter", x = "displacement", y ="mpg")
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='mpg'>

# %%
plt.scatter(data = df1, x = "displacement", y = "mpg")

# %%
sns.lineplot(data = df1, x = "model year", y = "mpg", hue = "origin", palette=['red', 'green', 'blue'])
# Out:
# <AxesSubplot:xlabel='model year', ylabel='mpg'>

# %%
fig, ax = plt.subplots()
for key, grp in df1.groupby(['origin']):
    ax.plot(grp['model year'], grp['mpg'], label=key)
ax.legend()
plt.show()

# %%
df1.cylinders.unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
sns.histplot(df1["cylinders"], bins = 5)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='Count'>

# %%
plt.hist(data = df1, x = "cylinders", bins = 5)
# Out:
# (array([  4., 204.,   3.,  84., 103.]),
#  array([3., 4., 5., 6., 7., 8.]),
#  <BarContainer object of 5 artists>)

# %%
sns.heatmap(df1[["mpg","cylinders","displacement","horsepower","weight","acceleration"]].corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.boxplot(df1.mpg)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a9ec792e50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a9ec78d9d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a9ec792ca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a9ec78dbb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a9ec78d100>],
#  'means': []}

# %%
df2 = pd.read_csv("../dataSet/AirPassengers.csv")
df2
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %%
sns.lineplot(data = df2, x = "Month", y = "#Passengers")
# Out:
# <AxesSubplot:xlabel='Month', ylabel='#Passengers'>

# %%
sns.histplot(df2["#Passengers"], bins = 10)
# Out:
# <AxesSubplot:xlabel='#Passengers', ylabel='Count'>

# %%
sns.kdeplot(df2["#Passengers"])
# Out:
# <AxesSubplot:xlabel='#Passengers', ylabel='Density'>

# %%
df2.describe()
# Out:
#        #Passengers
# count   144.000000
# mean    280.298611
# std     119.966317
# min     104.000000
# 25%     180.000000
# 50%     265.500000
# 75%     360.500000
# max     622.000000

# %%
sns.boxplot(df2["#Passengers"])
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(df2["#Passengers"])
# Out:
# <AxesSubplot:>
