# %% [markdown]
# ### pandas
# * 판다스는 Matplotlib 라이브러리의 기능을 일부 내장하고 있어서 별도로 임포드하지 않고 간단히 그래프 그릴 수 있음.
# * 선그래프 : df.plot()메소드 적용시 다른 옵션을 추가하지 않으면 가장 기본적인 선 그래프를 그림.
# * 막대 그래프 : df.plot(kind='bar'), df.plot(kind='barh',stacked=True,alpha=0.8)
# * 히스토그램 : df.plot(kind='hist') 그 컬럼의 분포를 볼 수 있음. ex) 인구분포도
# * 산점도 : df.plot(x=' ', y=' ', kind='scatter'), 상관관계를 볼 수 있음.
# * 박스 플롯 : df.plot(kind='box'), df.boxplot(column=['feature']) 특정 변수의 데이터 분포와 분산 정도에 대한 정보를 제공.
#
# ## matplotlib
# - histogram : plt.hist(x, bins= )
# - line plot : plt.plot(x,y)
# - plt.bar(x,y, width= , color='')
# - scatter plot : plt.scatter(x, y):
#
# ## seaborn
#     - matplotlib과 같이 쓰는게 편함
# - sns.distplot(data, bins=, color=, kde=), histplot, displot으로 변경
# - sns.boxplot(x, y, data, color)
# - sns.violinplot(x, y, data, color)
# - sns.barplot(x, y, data, color)
# - sns.jointplot(x, y, data, color)
# - sns.pairplot(data, hue, palette)
# - sns.lmplot(x,y,data,color)
# - sns.regplot(x,y,data,fig_reg=False)

# %% [markdown]
# ### 사용방법
#
# 1. pandas
# - 선그래프 : df.plot()
# - 막대 그래프 : df.plot(kind='bar',figsize=(10,5)), df.plot(kind='barh',stacked=True,alpha=0.8)
# - 수평 막대 그래프 : df.plot(kind='barh',color='skyblue'), df.plot.barh( )
# - 히스토그램 : df.plot(kind='hist')
# - 산점도 : df.plot(x=' ', y=' ', kind='scatter',figsize=(10,5))
# - 박스 플롯 : df.plot(kind='box'), df.boxplot(column=['feature'])
#
#
#
# 2. matplotlib
# - 스타일 : plt.style('ggplot')
# - 히스토그램 : plt.hist(x, bins= , label= )
# - 선그래프 : plt.plot(x,y)
# - 수직 막대그래프 : plt.bar(x,y, width= , color='')
# - 수평 막대 그래프: plt.barh(y,x), plt.yticks(y,years)
# - 산점도 : plt.scatter(x,y)
# - 파이 차트 : plt.pie(ratio, labels=labels, autopct='%.1f%%')
# - 박스 플롯 : plt.boxplot([data_a,data_b])
# - 바이올린 플럿 : plt.violinplot([data],showmeans=True)
#
# 3. seaborn
#
# - 두 변수 간의 관계를 시각화하는 그래프 :
#   sns.relplot(data=df,x=,y=,hue='')
#
# - 산점도 그래프 : scatterplot(data=df,x='',y='')
# - 선 그래프 : sns.lineplot(data=df,x='',y='',hue='',err_style='band')
# - 산점도+회귀선 그래프 : lmplot(data=df,x='',y='')
# - 산점도+회귀선 그래프 : regplot(data=df,x='',y='')
# - 히스토그램 그래프 : sns.histplot(data=df,x='',kde=True)
# - 밀도 그래프 : sns.kdeplot(data=df,x='')
# - 박스 그래프 : sns.boxplot(data=df,x='')
# - 바이올린 그래프 : sns.violinplot(data=df,x='')
# - 막대 그래프 : sns.barplot(data=df,x='',y='')                평균을 반영
# - 빈도수 그래프 : sns.countplot(x='',data=)                   말그대로 빈도수
# - 멀티 그래프 : sns.jointplot(data=df,x='',y='',kind='reg')
# - 히트맵 그래프 : sns.heatmap(df.[['columns']].corr(), annot=True)
# - 다변량 그래프 : sns.pairplot(df)

# %%
import pandas as pd

df = pd.read_csv('C:\hmkd1\m2_분석라이브러리\dataset/주가데이터.csv')
df.head()
# Out:
#           연월일   당일종가  전일종가     시가     고가     저가     거래량
# 0  2018-07-02  10100   600  10850  10900  10000  137977
# 1  2018-06-29  10700   300  10550  10900   9990  170253
# 2  2018-06-28  10400   500  10900  10950  10150  155769
# 3  2018-06-27  10900   100  10800  11050  10500  133548
# 4  2018-06-26  10800   350  10900  11000  10700   63039

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연월일     20 non-null     object
#  1   당일종가    20 non-null     int64
#  2   전일종가    20 non-null     int64
#  3   시가      20 non-null     int64
#  4   고가      20 non-null     int64
#  5   저가      20 non-null     int64
#  6   거래량     20 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.2+ KB

# %%
df.drop('전일종가',axis=1, inplace=True)
df.columns=['Date', 'Close', 'Start', 'High', 'Low', 'Volume']
df.head()
# Out:
#          Date  Close  Start   High    Low  Volume
# 0  2018-07-02  10100  10850  10900  10000  137977
# 1  2018-06-29  10700  10550  10900   9990  170253
# 2  2018-06-28  10400  10900  10950  10150  155769
# 3  2018-06-27  10900  10800  11050  10500  133548
# 4  2018-06-26  10800  10900  11000  10700   63039

# %%
df.to_pickle('../dataset/sprice.pkl')
df = pd.read_pickle('../dataset/sprice.pkl')
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Close   20 non-null     int64
#  2   Start   20 non-null     int64
#  3   High    20 non-null     int64
#  4   Low     20 non-null     int64
#  5   Volume  20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB

# %%
# Q. NDate 칼럼을 datetime 타입으로 생성하고 인덱스로 셋팅하세요.
# 컬럼 선택: 'Close' 'Start' 'High' 'Low'
df['NDate'] = pd.to_datetime(df['Date'])
df.set_index('NDate', inplace=True)
df1 = df[['Close','Start','High','Low']]
df1.head()
# Out:
#             Close  Start   High    Low
# NDate
# 2018-07-02  10100  10850  10900  10000
# 2018-06-29  10700  10550  10900   9990
# 2018-06-28  10400  10900  10950  10150
# 2018-06-27  10900  10800  11050  10500
# 2018-06-26  10800  10900  11000  10700

# %%
# 선그래프가 기본임

df1.plot()
# Out:
# <AxesSubplot:xlabel='NDate'>

# %%
# 막대 그래프
df.Volume[::-1].plot(kind='bar') # 순서를 거꾸로 해서 보겠음    
# 거래량을 막대그래프로 보는게 좋음
# Out:
# <AxesSubplot:xlabel='NDate'>

# %%
# 6월말 추출하여 Close 칼럼으로 일별 막대 그래프 표현
df1.loc['2018-6','Close'][::-1].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='NDate'>

# %%
# df1.loc['2018-6','Close'][::-1].plot(kind='barh',color='skyblue')
df1.loc['2018-6','Close'][::-1].plot.barh()
# Out:
# <AxesSubplot:ylabel='NDate'>

# %%
# 히스토그램 : 변수의 도수분포
df1.Close.plot(kind='hist',bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(x='Close',y='Volume',kind='scatter')


# 예측 선을 구해서 오차들의 합이 최소화 되면 최적
# Out:
# <AxesSubplot:xlabel='Close', ylabel='Volume'>

# %%
# 상관계수

df.corr()
# Out:
#            Close     Start      High       Low    Volume
# Close   1.000000  0.856181  0.941201  0.946297  0.441466
# Start   0.856181  1.000000  0.961009  0.921467  0.337829
# High    0.941201  0.961009  1.000000  0.945487  0.484145
# Low     0.946297  0.921467  0.945487  1.000000  0.246323
# Volume  0.441466  0.337829  0.484145  0.246323  1.000000

# %%
df.Close.describe()
# Out:
# count       20.000000
# mean     11662.500000
# std        927.060294
# min      10100.000000
# 25%      11087.500000
# 50%      11725.000000
# 75%      11962.500000
# max      13450.000000
# Name: Close, dtype: float64

# %%
# box plot
df.Close.plot(kind='box')

# 박스 밑이 25%에 해당하는 1사분위
# 박스 위 부분은 75%에 해당하는 3사분위
# 초록선이 50% 중앙값
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Box plot 의미 해석
#
# * IQR(Inter Quartile Range): 제 3사분위수 - 제1사분위수
# * lower whisker: Q1 - 1.5 x IQR 이내인 값중에서 최솟값
# * upper whisker: Q3 + 1.5 x IQR 이내인 값중에서 최댓값
# * 이상치: lower whisker, upper whisker를 벗어나는 값

# %%
# 이상치
Q1 = df.Close.describe()['25%']
Q3 = df.Close.describe()['75%']
IQR = Q3 - Q1
abv  = df[(df['Close'] <= (Q1-IQR*1.5))  |  (df['Close'] >= (Q1-IQR*1.5))]
abv
# Out:
#                   Date  Close  Start   High    Low  Volume
# NDate
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769
# 2018-06-27  2018-06-27  10900  10800  11050  10500  133548
# 2018-06-26  2018-06-26  10800  10900  11000  10700   63039
# 2018-06-25  2018-06-25  11150  11400  11450  11000   55519
# 2018-06-22  2018-06-22  11300  11250  11450  10750  134805
# 2018-06-21  2018-06-21  11200  11350  11750  11200  133002
# 2018-06-20  2018-06-20  11550  11200  11600  10900  308596
# 2018-06-19  2018-06-19  11300  11850  11950  11300  180656
# 2018-06-18  2018-06-18  12000  13400  13400  12000  309787
# 2018-06-15  2018-06-15  13400  13600  13600  12900  201376
# 2018-06-14  2018-06-14  13450  13200  13700  13150  347451
# 2018-06-12  2018-06-12  13200  12200  13300  12050  558148
# 2018-06-11  2018-06-11  11950  12000  12250  11950   62293
# ...

# %%
# upper whisker 산출 기준 : Q3 + 1.5 * IQR  이내인 값 중에서 최댓값
Q3 + IQR * 1.5
# Out:
# 13275.0

# %%
# upper whisker = 13200
# 이상치 : upper whisker를 벗어나는 값
df.sort_values('Close',ascending = False)[['Close']].head()
# Out:
#             Close
# NDate
# 2018-06-14  13450
# 2018-06-15  13400
# 2018-06-12  13200
# 2018-06-05  12150
# 2018-06-18  12000

# %%
df.head()
# Out:
#                   Date  Close  Start   High    Low  Volume
# NDate
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769
# 2018-06-27  2018-06-27  10900  10800  11050  10500  133548
# 2018-06-26  2018-06-26  10800  10900  11000  10700   63039

# %%
# Q. Start 칼럼의 분포 및 이상치 여부를 탐색하는 Box Plot 및 이상치를 구하세요.

df.Start.plot(kind = 'box')

# 이상치
Q1_s = df.Start.describe()['25%']
Q3_s = df.Start.describe()['75%']
IQR_s = Q3_s - Q1_s
abv  = df[(df['Start'] <= (Q1_s-IQR_s*1.5))  |  (df['Start'] >= (Q1_s-IQR_s*1.5))]
abv

print(Q3_s + IQR_s * 1.5)
df.sort_values('Start',ascending = False)[['Start']].head()
# Out:
# 13437.5
#             Start
# NDate
# 2018-06-15  13600
# 2018-06-18  13400
# 2018-06-14  13200
# 2018-06-07  12200
# 2018-06-12  12200

# %%
# 이상치 찾는 사용자함수

def low_whisker(dataframe,col):
    Q1 = col.describe()['25%']
    Q3 = col.describe()['75%']
    IQR = Q3 - Q1
    abv  = dataframe[(col <= (Q1-IQR*1.5))  |  (col >= (Q3+IQR*1.5))]
    return abv


print(low_whisker(df, df.Start))  # 여기서 나온 데이터만 제거하면 되는 것
# Out:
#                   Date  Close  Start   High    Low  Volume
# NDate
# 2018-06-15  2018-06-15  13400  13600  13600  12900  201376

# %% [markdown]
# #### 과제. High, Low 컬럼에 대하여 이상치 여부를 시각화로 확인 후 그 값을 구하세요.

# %%
# High 이상치
df.High.plot(kind = 'box')

Q1_h = df.High.describe()['25%']
Q3_h = df.High.describe()['75%']
IQR_h = Q3_h - Q1_h
print(Q3_h + IQR_h * 1.5)
# Out:
# 13631.25

# %%
# Low 이상치
df.Low.plot(kind = 'box')

Q1_l = df.Low.describe()['25%']
Q3_l = df.Low.describe()['75%']
IQR_l = Q3_l - Q1_l
print(Q3_l + IQR_l * 1.5)
# Out:
# 13675.0

# %%
# 남북한의 연도별 발전량 데이터 셋
# Q. 남북한 발전량 데이터를 시각적으로 탐색하고 그 특징을 요약 기술하세요.
df_ep = pd.read_excel('../dataset/df_ep.xlsx')
df_ep.head()


df_ep.set_index('year',inplace = True)
df_ep.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# #### 과제. df_auto의 각 칼럼을 시각화해서 탐색한 후 인사이트를 기술하세요. (5개 이상)
#
# - 예를 들어 70-80년도에는 오일쇼크로 인해서 어떻게 변화가 되었는지
# - 그래프와 데이터들을 보면 mpg는 증가하고 경량화하는 경우가 많더라. 이를 잘한 나라가 일본이다.

# %% [markdown]
# 과제.mpg 컬럼의 이상치 여부를 판단하고 의심되는 값이 있는 경우 제거하세요.

# %%
import pandas as pd

df_auto = pd.read_excel('../dataset/auto-mpg.xlsx')
print(df_auto.head(),'\n')
print(df_auto.describe(),'\n')
df_auto.corr()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
#
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# ...

# %%
df_auto.plot(x='mpg',y='cylinders',kind='scatter')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='cylinders'>

# %%
df_auto.plot(x='mpg',y='displacement',kind='scatter')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
df_auto.plot(x='mpg',y='weight',kind='scatter')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='weight'>

# %%
df_auto.plot(x='mpg',y='acceleration',kind='scatter')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='acceleration'>

# %%
df_auto.plot(x='mpg',y='model year',kind='scatter')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='model year'>

# %%
# mpg 이상치
df_auto.mpg.plot(kind = 'box')

Q1= df_auto.mpg.describe()['25%']
Q3 = df_auto.mpg.describe()['75%']
IQR = Q3 - Q1
uwc = Q3 + IQR * 1.5     # upper whisker를 따지기 위한 기준일 뿐. upper whisker는 아님
uw = df_auto.mpg[df_auto.mpg <= uwc].max()
print('upper whisker : ',uw)
print('이상치 : ', df_auto.mpg[df_auto.mpg>uw].values[0])
# Out:
# upper whisker :  44.6
# 이상치 :  46.6

# %%
# 이상치 삭제
Q1 = df_auto.mpg.describe()['25%']
Q3 = df_auto.mpg.describe()['75%']
IQR = Q3 - Q1

uwc = Q3+IQR*1.5
idx_uw = df_auto[df_auto.mpg <= uwc].mpg.idxmax()

idx = df_auto[df_auto.mpg > df_auto.loc[idx_uw,'mpg']].index[0]
idx
df = df_auto.drop(df_auto.index[idx])

df.sort_values('mpg',ascending=False)[['mpg']].head()
# Out:
#       mpg
# 329  44.6
# 325  44.3
# 394  44.0
# 326  43.4
# 244  43.1

# %%
df_auto.[['mpg'()]]
# Out:
#   File "C:\Users\h\AppData\Local\Temp\ipykernel_41780\873957378.py", line 1
#     df_auto.[['mpg'()]]
#             ^
# SyntaxError: invalid syntax

# %%
# 변수에는 연속형과 범주형(형태가 이산형, 끊어져 있는 형태)
# 상관관계를 보이는 것은 연속형
# 범주형인 것들은 범주형으로 봐야 함

# %% [markdown]
# #### Matplotlib
# - 파이썬에서 사용되는 대표적인 데이터 시각화 라이브러리.
# - 2D, 3D 그래프, 히스토그램, 산점도, 파이차트 등 다양한 그래프를 지원하며,
# - 사용자가 그래프의 세부적인 설정을 조절할 수 있도록 다양한 옵션을 제공
# - 핵심적인 개념은 Figure(그림)와 Axes(축)
# - Figure는 그래프 전체를 의미하며, 하나의 Figure에 여러 개의 Axes를 추가하여 서로 다른 그래프를 그림
# - Axes는 Figure 내부의 그래프 영역을 의미하며, x축과 y축을 포함한 그래프 요소들을 생성하는 역할
# <br><br>
# 그래프 선 옵션<br>
# 그래프를 그릴 때 표시 되는 색이나 마커 패턴을 바꾸는 것 확인할 수 있다.<br>
# 색상: b(파란색), g(초록색), r(빨간색), c(청록색), y(노란색), k(검은색), w(흰색)<br>
# 마커: o(원), v(역삼각형), ^(삼각형), s(네모), +(플러스), .(점)

# %%
import matplotlib.pyplot as plt

# 데이터 생성
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]  # 2씩 곱한 값이 y이기에 비례해서 갈 것임

# 크기 조절
plt.figure(figsize = (6,5))      # 800*500 사이즈

# 산점도 그래프 그리기
plt.scatter(x, y)

# 그래스 제목, x축 레이블, y축 레이블 설정
plt.title("Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# 그래프 출력
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 생성
y = []
x = np.linspace(1,10,100)
for i in x:
    r = i+np.random.normal(0,1)        # 표준정규분포
    y.append(r) 


# 크기 조절
plt.figure(figsize = (8,5))      # 800*500 사이즈

# 산점도 그래프 그리기
plt.scatter(x, y)

# 그래스 제목, x축 레이블, y축 레이블 설정
plt.title("Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
 
# 그래프 출력
plt.show()

# %%
x = np.arange(1,19,2)
y = np.array([3,5,6,13,30,21,22,29,33.32])
plt.figure(figsize=(6,4))
plt.plot(x,y,color = 'blue',marker = 'o', markersize = 3)
plt.title('Lineplot Matplotlib', size = 20)
plt.xlabel('x',size = 15)
plt.ylabel('y',size = 15)
plt.legend(labels = ['lineplot'])

# %%
# 선 그래프 두개 그리기

np.random.seed(0)     # 랜덤 고정
x = np.arange(20)
y1 = np.arange(20)*2 + np.random.randn(20)*10
y2 = np.arange(20)*2 + np.random.randn(20)

plt.figure(figsize=(6,4))
plt.plot(x,y1)
plt.plot(x,y2,color = 'magenta',marker = 'o', markersize = 5)
plt.title('Line Graph', size = 25)
plt.xlabel('x',size = 15)
plt.ylabel('y',size = 15)
plt.legend(['A','B'])

# %%
# Q. 두 개의 데이터 셋을 생성한 후 Line Graph를 작성하세요.

import numpy as np
np.random.seed(0)
import matplotlib.pyplot as plt

x= np.arange(30)
y1= np.arange(30)+np.random.randn(30)*3
y2= np.arange(30)+np.random.rand(30)
plt.figure(figsize=(7,4))
plt.plot(x,y1)
plt.plot(x,y2, color='tomato',marker='s',markersize=3)

plt.title("Temperature Trend")
plt.xlabel('Date',size=10)
plt.ylabel('Temperture',size=10)
plt.legend(['r1','r2'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 막대 그래프 : 지역별 소득수준
y = np.random.randint(2,10,size=10)
x = range(len(y))
print(x)
print(y)
plt.figure(figsize=(8,4))
plt.bar(x,y,width=0.8,color='skyblue')
plt.title('Income level by region',size=30,color='gray')
plt.ylabel('y',size=20,color='gray')
plt.xlabel('x',size=20,color='gray')
# Out:
# range(0, 10)
# [4 6 4 2 7 5 4 4 7 2]
# Text(0.5, 0, 'x')

# %%
# 수평 막대 그래프

# 데이터 생성
x = [10, 20, 30, 40, 50]
y = ['A','B','C','D','E']

# 수평 막대 그래스 (brah) 그리스
plt.barh(y,x)

# x축 레이불, y축 레이블, 그래프 제목 추가

plt.xlabel('Value')
plt.ylabel('Category')
plt.title('Horizontal Bar Graph')

# 그래프 보여주기
plt.show()

# %%
# 수직, 수평 막대 그래프를 할 번에 같이 비교해서 보기

fig = plt.figure(figsize=(8,6))
ax1 = fig.add_subplot(2,1,1)              # 2행 1열 첫번째에 ax1를 둔다.
ax2 = fig.add_subplot(2,1,2)

ax1.bar(y,x)
ax2.barh(y,x)
# Out:
# <BarContainer object of 5 artists>

# %%
# Q. 막대그래프가 적합한 case를 생성한 후 수평, 수직 막대그래프를 같이 표현하는 시각화를 수행하세요.

np.random.seed(1)
x = np.arange(10,100,10)
y = np.random.randint(100,1500,9)



fig = plt.figure(figsize=(8,10))

ax1 = fig.add_subplot(2,1,1)
plt.title("Hometown",size=30)
plt.xlabel("age",size=10)
plt.ylabel("Population",size=10)

ax2 = fig.add_subplot(2,1,2)
plt.ylabel("age",size=10)
plt.xlabel("Population",size=10)


ax1.bar(x,y,color="red", width=5)
ax2.barh(x,y,height=5)
# Out:
# <BarContainer object of 9 artists>

# %%
# 막대그래프 연습
x=[112.6, 64.2, 37.9, 59.1, 78.8, 278.9, 524.1, 193.1, 241.7, 20.5, 55.6, 6.3]    #창원지방 월별 강수량
y=np.arange(1,13)   #월

fig = plt.figure(figsize=(8,10))     # 이 창의
ax1 = fig.add_subplot(2,1,1)   # 2행 1열 첫 번째 자리에 그래프를 넣어라
ax2 = fig.add_subplot(2,1,2)   # 2행 1열 두 번째

ax1.bar(y,x, color='deepskyblue')  # x,y값 반대로 넣어주기
ax2.barh(y,x, color='lightskyblue')  # x,y값 반대로 넣어주기

ax1.set_xlabel('month')
ax1.set_ylabel('rain')

ax2.set_xlabel('rain')
ax2.set_ylabel('month')
# Out:
# Text(0, 0.5, 'month')

# %%
# scatter plot

df_auto = pd.read_excel('../dataset/auto-mpg.xlsx')
x = df_auto.mpg
y = df_auto.weight
plt.figure(figsize=(8,6))
plt.scatter(x,y,color='blue')

# %%
# histogram

plt.figure(figsize=(10,6))
plt.hist(df_auto.mpg,bins=10,color='magenta')
# Out:
# (array([13., 78., 73., 61., 54., 48., 38., 22.,  5.,  6.]),
#  array([ 9.  , 12.76, 16.52, 20.28, 24.04, 27.8 , 31.56, 35.32, 39.08,
#         42.84, 46.6 ]),
#  <BarContainer object of 10 artists>)

# %%
fig = plt.figure(figsize=(10,6))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax2.hist(np.random.rand(1000), bins=20, color='k', alpha=0.5)
ax3.plot(np.random.randn(50).cumsum(),'k--')
# ax3.plot(x,y,'k--')
ax4.scatter(np.arange(30), np.arange(30)+3*np.random.randn(30))

# %%
plt.figure(figsize=(10,6))
plt.hist(df_auto.weight,bins=10,color='green')
# Out:
# (array([31., 90., 59., 54., 37., 40., 29., 34., 18.,  6.]),
#  array([1613. , 1965.7, 2318.4, 2671.1, 3023.8, 3376.5, 3729.2, 4081.9,
#         4434.6, 4787.3, 5140. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### 과제1. 각 그래프로 표현할 수 있는 적합한 4개의 데이터 셋을 생성하여 히스토그램, 막대그래프, 선그래프, 산점도로 2행 2열로 표현하세요.

# %%
# 과제: 4개 데이터셋을 히스토, 막대, 선, 산점도로 뽑기
df_auto.replace('?',np.nan, inplace=True)
df_auto.dropna()

fig = plt.figure(figsize=(10,6))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1.hist(df_auto.cylinders, bins=20, color='m', alpha=0.3)
# 실린더 개수 분포 확인
ax2.plot(df_auto['model year'], df_auto['mpg'], 'b--')
ax3.scatter(df_auto['displacement'], df_auto['mpg'], color='gold')
# 배기량과 연비의 관계
ax4.barh(df_auto['cylinders'], df_auto['horsepower'], color='lightgreen', height=0.3)
# 실린더 개수별 마력

# ax1.hist(dfat.displacement, bins=20, color='m', alpha=0.3)
# ax2.plot(dfat['model year'], dfat['mpg'], 'b--')
# ax3.scatter(dfat['acceleration'], dfat['horsepower'], color='gold')
# ax4.barh(dfat['cylinders'], dfat['horsepower'], color='lightgreen', height=0.3)
# Out:
# <BarContainer object of 398 artists>

# %%
fig = plt.figure(figsize=(10,6))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)



ax1.hist()
ax2
ax3.plot()
ax4.scatter(x = df_auto.mpg, y = df_auto.weight, 'b+')
# Out:
#   File "C:\Users\h\AppData\Local\Temp\ipykernel_41780\1205172367.py", line 12
#     ax4.scatter(x = df_auto.mpg, y = df_auto.weight, 'b+')
#                                                          ^
# SyntaxError: positional argument follows keyword argument

# %%
# 샘플 수의 변화에 따른 분포 모습
fig,axes = plt.subplots(2,3,figsize = (20,10))     # fig와 축을 뽑음
axes[0,0].hist(np.random.randn(100),bins=50)      # 표준정규분포에서 50개를 뽑겠다. 
axes[0,1].hist(np.random.randn(1000),bins=50)     # 샘플을 늘릴 수록 표준정규분포가 점점 매끄럽게 됨
axes[0,2].hist(np.random.randn(10000),bins=50)
axes[1,0].hist(np.random.randn(100000),bins=50)
axes[1,1].hist(np.random.randn(1000000),bins=50)
axes[1,2].hist(np.random.randn(10000000),bins=50)

# %%
# 색상, 마커, 선 스타일

from numpy.random import randn

np.random.seed(1)         # randn 을 입포트해서 random 만 씀

plt.figure(figsize = (10,6))
# plt.plot(randn(30).cumsum(),linestyle='dashed',color='b',marker='o')
plt.plot(randn(30).cumsum(),'b--',marker='o')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# plt.style.use('ggplot')
plt.style.use('default')      # 그래프 스타일 원래대로 바꾸기
np.random.seed(1)         # randn 을 입포트해서 random 만 씀

plt.figure(figsize = (10,6))
# plt.plot(randn(30).cumsum(),linestyle='dashed',color='b',marker='o')
plt.plot(randn(30).cumsum(),'b--',marker='o')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41780\1428587980.py in <module>
#       5 plt.figure(figsize = (10,6))
#       6 # plt.plot(randn(30).cumsum(),linestyle='dashed',color='b',marker='o')
# ----> 7 plt.plot(randn(30).cumsum(),'b--',marker='o')
#
# NameError: name 'randn' is not defined

# %%
np.random.seed(0)
data = np.random.randn(1000)
cdata = data.cumsum()
print(data[:10])
cdata[:10]
# Out:
# [ 1.76405235  0.40015721  0.97873798  2.2408932   1.86755799 -0.97727788
#   0.95008842 -0.15135721 -0.10321885  0.4105985 ]
# array([1.76405235, 2.16420955, 3.14294754, 5.38384074, 7.25139873,
#        6.27412085, 7.22420927, 7.07285206, 6.96963321, 7.38023171])

# %%
# 한글 폰트 깨지는걸 처리해주기 위해

import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font',family = 'Malgun Gothic') # 한글 폰트 설정
plt.rcParams['axes.unicode_minus'] = False    # 마이너스 부호 출력 설정
fig = plt.figure(figsize = (12,6))
ax = fig.add_subplot(1,1,1)    # 1행 1열에 1개
ax.plot(cdata)
ticks = ax.set_xticks([0,250,500,750,1000])
labels = ax.set_xticklabels(['one','two','three','four','five'],
                           rotation = 30, fontsize = 'small')
ax.set_title('제목, 축이름, 눈금, 눈금 이름 설정', size =20)
ax.set_xlabel('Stages',size = 20)
ax.set_ylabel('Sum',size = 20)
# Out:
# Text(0, 0.5, 'Sum')

# %%
# 범례추가

from numpy.random import randn
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(1,1,1)   # subplot은 하나만 해놓고 ax에 3개를 넣으면 한꺼번에 볼 수 잇음
ax.plot(randn(1000).cumsum(),'m',label = 'one')
ax.plot(randn(1000).cumsum(),'g',label = 'two')
ax.plot(randn(1000).cumsum(),'b',label = 'three')
plt.legend(loc='best')            # legend 범례

# %%
import seaborn as sns
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
def get_age_cat(age):
    cat = ''
    if age <15: cat = 'young'
    elif age <30: cat = 'teen'
    elif age <45: cat = 'adult'
    elif age <60: cat = 'mature'
    else: cat = 'elder'
    return cat

df['age_cat'] = df['age'].apply(lambda x : get_age_cat(x))
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone age_cat
# 0    man        True  NaN  Southampton    no  False    teen
# 1  woman       False    C    Cherbourg   yes  False   adult
# 2  woman       False  NaN  Southampton   yes   True    teen
# 3  woman       False    C  Southampton   yes  False   adult
# 4    man        True  NaN  Southampton    no   True   adult

# %%
df['Ratio'] = 1       # 새로운 열인 Ratio에 각 값에 1을 준 것.

df_age_cat = df.groupby('age_cat').sum()        # 그래서 합을 Ratio에 넣어준 것
df_age_cat
# Out:
#          survived  pclass      age  sibsp  parch       fare  adult_male  \
# age_cat
# adult          91     457  7667.00     76     83  8532.2664         137
# elder          59     500  1692.50    106     40  5052.2330         146
# mature         36     146  4483.50     30     27  3893.7461          57
# teen          111     749  6908.50    112     87  8742.7579         197
# young          45     205   453.67    142    103  2472.9459           0
#
#          alone  Ratio
# age_cat
# adult      130    215
# elder      152    203
# mature      53     89
# teen       198    306
# young        4     78

# %%
df['Ratio'] = 1       # 각 값에 1을 준 것. ㅅ

df_age_cat = df.groupby('age_cat').sum()
df_age_cat.Ratio.plot(kind = 'pie',
                     figsize = (8,6),
                     autopct = '%.2f%%', # 원 그래프 안에 표시할 것을 설정
                     startangle = 0)
plt.title('Age Category',size = 20)
plt.axis('equal')
plt.legend(labels = df_age_cat.index,loc = 'best')

# %% [markdown]
# #### 과제2 fare를 5개로 범주화하여 fare_cat 컬럼을 생성하고 파이차트로 시각화 하세요.

# %%
import seaborn as sns
titanic_df = sns.load_dataset('titanic')
print(titanic_df.fare.describe())
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
def get_fare_cat(fare):
    cat = ''
    if fare <7: cat = '5'
    elif fare <10: cat = '4'
    elif fare <15: cat = '3'
    elif fare <35: cat = '2'
    else: cat = '1'
    return cat

df['fare_cat'] = df['fare'].apply(lambda x: get_fare_cat(x))
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone age_cat  Ratio fare_cat
# 0    man        True  NaN  Southampton    no  False    teen      1        4
# 1  woman       False    C    Cherbourg   yes  False   adult      1        1
# 2  woman       False  NaN  Southampton   yes   True    teen      1        4
# 3  woman       False    C  Southampton   yes  False   adult      1        1
# 4    man        True  NaN  Southampton    no   True   adult      1        4

# %%
df['Ratio_f'] = 1
df_fare_cat = df.groupby('fare_cat').sum()
df_fare_cat.Ratio.plot(kind = 'pie',
                      figsize = (8,6),
                      autopct = '%.2f%%',
                      startangle = 0)
plt.title('fare Category',size = 20)
plt.axis('equal')
plt.legend(labels = df_fare_cat.index,loc = 'best')

# %% [markdown]
# #### 과제3.
# Fifa 데이터셋에서 'International Reputation' 컬럼에 대해서 파이차트로 시각화하세요.

# %%
import pandas as pd
data = pd.read_csv('../dataset/data.csv',index_col=0)
data.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
print(data['International Reputation'].head(),'\n')

pd.DataFrame(data['International Reputation'])
# Out:
# 0    5.0
# 1    5.0
# 2    5.0
# 3    4.0
# 4    4.0
# Name: International Reputation, dtype: float64
#        International Reputation
# 0                           5.0
# 1                           5.0
# 2                           5.0
# 3                           4.0
# 4                           4.0
# ...                         ...
# 18202                       1.0
# 18203                       1.0
# 18204                       1.0
# 18205                       1.0
# 18206                       1.0
#
# [18207 rows x 1 columns]

# %%
data['International Reputation'].value_counts()
# Out:
# 1.0    16532
# 2.0     1261
# 3.0      309
# 4.0       51
# 5.0        6
# Name: International Reputation, dtype: int64

# %%
data['Ratio'] = 1         # 이름 다른거 넣어도 상관없음. 새로운 열 추가

dfIR = data.groupby(['International Reputation']).sum()           # 함수이기에 () 있어야 함

dfIR.Ratio.plot(kind='pie',
                figsize=(8,6),
                autopct='%.2f%%',
                startangle=0)
plt.title('International Reputation', size=20)
plt.axis('equal') # 가로와 세로의 비율을 동일하게 설정
plt.legend(labels=data['International Reputation'].index,loc='best')          # df.(){} 없어야 하고 df에 바로 쓰려면 (),[] 필요

# %%
# 물고기 길이 데이터
df = pd.read_csv('../dataset/4_fm2.csv')
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
ax1.boxplot(x=[df[df['species']=='A']['length'],                   # 종이 A인 것의 길이와 종이 B인 것의 길이를 위 아래로 본다
           df[df['species']=='B']['length']])
ax2.boxplot(x=[df[df['species']=='A']['length'],                   # 종이 A인 것의 길이와 종이 B인 것의 길이를 좌 우로 
           df[df['species']=='B']['length']],vert=False)
ax1.set_title('Speices 별 length 분포 - 수직 박스')
ax2.set_title('Speices 별 length 분포 - 수평 박스')
# Out:
# Text(0.5, 1.0, 'Speices 별 length 분포 - 수평 박스')

# %% [markdown]
# #### 과제4.
# Fifa 데이터셋에서 Wage 컬럼을 전처리해서 시각화하고 데이터가 가지고 있는 의미를 설명하세요.

# %%
data = pd.read_csv('../dataset/FIFA.csv',encoding='euc-kr')
data.head()
# Out:
#        ID               Name  Age Nationality  Overall                 Club  \
# 0  158023           L. Messi   31   Argentina       94         FC Barcelona
# 1   20801  Cristiano Ronaldo   33    Portugal       94             Juventus
# 2  190871          Neymar Jr   26      Brazil       92  Paris Saint-Germain
# 3  193080             De Gea   27       Spain       91    Manchester United
# 4  192985       K. De Bruyne   27     Belgium       91      Manchester City
#
#   Preferred_Foot       Work_Rate Position  Jersey_Number  \
# 0           Left  Medium/ Medium       RF             10
# 1          Right       High/ Low       ST              7
# 2          Right    High/ Medium       LW             10
# 3          Right  Medium/ Medium       GK              1
# 4          Right      High/ High      RCM              7
#
#    Contract_Valid_Until Height  Weight_lb  Release_Clause   Value  Wage
# 0                  2021    5'7        159          226500  110500   565
# ...

# %%
data.Wage.head()
# Out:
# 0    565
# 1    405
# 2    290
# 3    260
# 4    355
# Name: Wage, dtype: int64

# %%
print(data.Wage.value_counts(),'\n')
print(data.Wage.describe())

data.Wage.isnull().sum()        # 결측치가 없으니까 이상치 제거만 하면 됨.
# Out:
# 1      4770
# 2      2704
# 3      1734
# 4      1137
# 5       763
#        ...
# 250       1
# 190       1
# 93        1
# 405       1
# 565       1
# Name: Wage, Length: 141, dtype: int64
#
# count    16642.000000
# mean         9.618375
# std         22.264145
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          8.000000
# max        565.000000
# Name: Wage, dtype: float64
# 0

# %%
pd.DataFrame(data.Wage)
# Out:
#        Wage
# 0       565
# 1       405
# 2       290
# 3       260
# 4       355
# ...     ...
# 16637     1
# 16638     1
# 16639     1
# 16640     1
# 16641     1
#
# [16642 rows x 1 columns]

# %%
def low_whisker(dataframe,col):
    Q1 = col.describe()['25%']
    Q3 = col.describe()['75%']
    IQR = Q3 - Q1
    abv  = dataframe[(col <= (Q1-IQR*1.5))  |  (col >= (Q3+IQR*1.5))]
    return abv


print(low_whisker(data,data.Wage))
# Out:
#           ID               Name  Age Nationality  Overall  \
# 0     158023           L. Messi   31   Argentina       94
# 1      20801  Cristiano Ronaldo   33    Portugal       94
# 2     190871          Neymar Jr   26      Brazil       92
# 3     193080             De Gea   27       Spain       91
# 4     192985       K. De Bruyne   27     Belgium       91
# ...      ...                ...  ...         ...      ...
# 7650  209852        B. Galloway   22     England       67
# 7896  245238       Javi S?nchez   21       Spain       67
# 8260  225105    Cristo Gonz?lez   20       Spain       66
# 9202  241467    F. Feuillassier   20   Argentina       65
# 9287  246608            Fidalgo   21       Spain       65
#
#                      Club Preferred_Foot       Work_Rate Position  \
# 0            FC Barcelona           Left  Medium/ Medium       RF
# 1                Juventus          Right       High/ Low       ST
# 2     Paris Saint-Germain          Right    High/ Medium       LW
# ...

# %%
x = data.ID
y = data.Wage
plt.figure(figsize=(8,6))
plt.scatter(x,y,color='blue')

# %% [markdown]
# #### 과제4.
# Fifa 데이터셋에서 Wage 컬럼을 전처리해서 시각화하고 데이터가 가지고 있는 의미를 설명하세요.

# %%
data = pd.read_csv('../dataset/data.csv',index_col=0)
data.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
data.Wage.value_counts()
# Out:
# €1K      4900
# €2K      2827
# €3K      1857
# €4K      1255
# €5K       869
#          ...
# €190K       1
# €235K       1
# €93K        1
# €405K       1
# €565K       1
# Name: Wage, Length: 144, dtype: int64

# %%
data.Wage.info()

# 숫자가 아닌 문자처리 되어있음. 그래서 이거를 숫자 표시해야함
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 18207 entries, 0 to 18206
# Series name: Wage
# Non-Null Count  Dtype
# --------------  -----
# 18207 non-null  object
# dtypes: object(1)
# memory usage: 284.5+ KB

# %%
import re
def get_num(x):
    result = int(re.sub('[^0-9]','',x))      # 0-9: 모든 숫자를 의미. ^ 아닌 것. 즉, ^0-9 : 숫자가 아닌 것은 ''공백으로 바꾸겠다는 것. 
    return result
data['Nwage'] = data.Wage.apply(lambda x:get_num(x))
data[['Wage','Nwage']].head()
# Out:
#     Wage  Nwage
# 0  €565K    565
# 1  €405K    405
# 2  €290K    290
# 3  €260K    260
# 4  €355K    355

# %%
data.Nwage.plot(kind='hist',bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.Nwage.describe()

# 100유로 이상은 별도로 봐야 함
# Out:
# count    18207.000000
# mean         9.731312
# std         21.999290
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          9.000000
# max        565.000000
# Name: Nwage, dtype: float64

# %%
data.Nwage[data.Nwage <= 100].plot(kind='hist',bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.Nwage[data.Nwage <= 100].describe()

# 비교하기가 어려움. 정규화나 표준화를 해서 스케일을 조정. 그러나, 이런 변수에 분포 이런 것을 활용하는데는 도움이 안됨
# 그래서 로그로 변환해서 조정. 급격한 차이를 완만하게 조정.
# Out:
# count    18022.000000
# mean         8.090556
# std         12.874957
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          8.000000
# max        100.000000
# Name: Nwage, dtype: float64

# %%
# 파이썬에서 로그 변환 :  np.log1p(x)

import numpy as np
def lognum(x):
    result = np.log1p(x)
    return result

data['Lwage'] = data.Nwage.apply(lambda x:lognum(x))       # 로그로 변환한 값 새로운 컬럼에 넣겠다는 것
data[['Nwage','Lwage']].head()
# Out:
#    Nwage     Lwage
# 0    565  6.338594
# 1    405  6.006353
# 2    290  5.673323
# 3    260  5.564520
# 4    355  5.874931

# %%
import seaborn as sns
sns. histplot(data.Lwage, bins = 20)
# Out:
# <AxesSubplot:xlabel='Lwage', ylabel='Count'>

# %%
data.Lwage.describe()
# Out:
# count    18207.000000
# mean         1.678575
# std          1.019503
# min          0.000000
# 25%          0.693147
# 50%          1.386294
# 75%          2.302585
# max          6.338594
# Name: Lwage, dtype: float64

# %% [markdown]
# #### seaborn
# - 파이썬의 시각화 라이브러리 중 하나로, matplotlib 라이브러리를 기반으로 하여 좀 더 다양한 시각화 기능과 스타일을 제공
#
# - seaborn의 특징
#     - matplotlib에 비해 더 간결하고 직관적인 API를 제공
#     - matplotlib의 스타일을 기본적으로 사용하지만, 좀 더 다양한 스타일을 제공
#     - 통계 분석에 사용되는 다양한 그래프를 제공
#     - pandas와 연동하여 데이터 시각화를 더욱 편리하게 수행
# - seaborn에서 제공하는 그래프
#     - relplot: 두 변수 간의 관계를 시각화하는 그래프
#     - scatterplot: 산점도 그래프
#     - lineplot: 선 그래프
#     - histplot: 히스토그램 그래프
#     - kdeplot: 밀도 그래프
#     - boxplot: 박스 그래프
#     - violinplot: 바이올린 그래프
#     - heatmap: 히트맵 그래프

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(8,6))

x=tips.total_bill
y=tips.tip
plt.scatter(x,y,color='pink')   #두 변수간의 관계 -> 스캐터플랏

# %%
# seaborn으로 출력
plt.figure(figsize=(10,6))
sns.scatterplot(x=x,y=y,data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41780\2222494272.py in <module>
#       1 plt.figure(figsize=(10,6))
# ----> 2 sns.lineplot(x,y)
#
# TypeError: lineplot() takes from 0 to 1 positional arguments but 2 were given

# %% [markdown]
# lineplot 함수는 여러 가지 옵션을 제공하며, 이를 사용하여 선 그래프를 더욱 자세하게 설정할 수 있습니다.
# - hue 옵션을 사용하여 'sex' 열의 값에 따라 선 그래프의 색상을 다르게 설정하고,
# - style 옵션을 사용하여 'smoker' 열의 값에 따라 선 그래프의 스타일을 다르게 설정
# - markers 옵션을 사용하여 데이터 포인트를 원형 모양으로 표시

# %%
plt.figure(figsize=(10,6))
# sns.lineplot(x='total_bill',y='tip',hue='sex',style='smoker',markers = True, data = tips)
sns.lineplot(x='total_bill',y='tip',hue='sex', data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# barplot : 범주형 변수에 대한 막대 그래프
# - x축에는 "day" 열의 값, y축에는 "total_bill" 열의 값이 사용됨
# - barplot 함수는 기본적으로 각 범주별로 y축 값의 평균과 오차 막대를 그리며,
# - ci 옵션을 사용하여 오차 막대의 크기를 조절

# %%
sns.barplot(x='day', y='total_bill', data = tips)


# 까만 막대는 오차 막대임
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#sd 표준편차, 오차 막대의 크기를 y 축 값의 표준편차로 설정
# palette 옵션을 사용해 막대 그래프의 색상을 변경할 수 있음

sns.barplot(x='day', y='total_bill',ci='sd', palette='Blues_d', data = tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Q. tip의 비중(tip_pct)을 구해서 요일별 팁의 비중을 보여주는 시각화를 수행하세요.
# 마진과 마크업의 차이
# 원가 800원인 상품을 1,000원에 팔면 마진, 마크업도 200원이다.
# 마진은 200/1000 20%, 마크업은 200/800 25%. 즉, 마크업은 원가를 기준으로 하고 마진은 가격을 기준으로 함
def pct(x):
    result = tips.tip(x)/tips.total_bill
    return result

tips['tip_pct'] = tips['tip']/(tips['total_bill']-tips['tip'])       # 마크업 개념. 
 

sns.barplot(x='tip_pct', y='day', palette='Oranges', data = tips, orient = 'h')
# Out:
# <AxesSubplot:xlabel='tip_pct', ylabel='day'>

# %%
sns.barplot(x='tip_pct', y='time', palette='Oranges', data = tips, orient = 'h')
# Out:
# <AxesSubplot:xlabel='tip_pct', ylabel='time'>

# %%
 # hue 어떤 걸 기준으로 할 것인지



sns.countplot('size',hue='time',data=tips, palette = 'bone')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41780\318527648.py in <module>
#       3
#       4
# ----> 5 sns.countplot('size',hue='time',data=tips, palette = 'bone')
#
# TypeError: countplot() got multiple values for argument 'data'

# %%
plt.figure(figsize = (8,5))
tips['tip_pct'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# kde = True: 밀도함수 추가

plt.figure(figsize = (8,5))
sns.histplot(tips['tip_pct'],bins=100,color='b',kde = True)
# Out:
# <AxesSubplot:xlabel='tip_pct', ylabel='Count'>

# %%
# 현재버전 확인
sns.__version__

# 버전에 따라 안 되는 기능도 있는데 그러면 버전을 확인 후 업그레이드 시키면 됨
# !pip install seaborn --upgrade

# %%
# 물고기 종류별 몸길이 데이터
import pandas as pd
fish_multi = pd.read_csv('../dataset/4_fm2.csv')
fish_multi.head()
# Out:
#   species  length
# 0       A       2
# 1       A       3
# 2       A       3
# 3       A       4
# 4       A       4

# %%
length_a = fish_multi[fish_multi.species == 'A']['length']
length_b = fish_multi[fish_multi.species == 'B']['length']
sns.histplot(length_a,kde = True)
sns.histplot(length_b,kde = True)
# sns.distplot(length_a,kde = True)
# Out:
# <AxesSubplot:xlabel='length', ylabel='Count'>

# %%
sns.boxplot(x='species', y='length',data=fish_multi, color = 'g')
# Out:
# <AxesSubplot:xlabel='species', ylabel='length'>

# %%
# 바이올린 플롯 : 상자 대신 히스토그램을 세로로 세워서 배치, 어느 부분에 데이터가 집중되어 있는지 보여줌

sns.violinplot(x='species',y='length',data=fish_multi,color='skyblue')

# A 종은 길이 4가 제일 많다는 것
# Out:
# <AxesSubplot:xlabel='species', ylabel='length'>

# %%
# regplot
# sns.regplot(data=tips, x='total_bill', y='tip')
# sns.lmplot(data=tips, x='total_bill', y='tip')
sns.regplot(data=tips, x='total_bill', y='tip',scatter_kws={'s':50,'color':'red,\
                                                            'alpha':0.5'})
sns.regplot(data=tips, x='total_bill', y='tip',\)
# Out:
#   File "C:\Users\h\AppData\Local\Temp\ipykernel_41780\1349574707.py", line 5
#     'alpha':0.5'})
#      ^
# SyntaxError: invalid syntax

# %%
# regplot
# sns.regplot(data=tips,x='total_bill',y='tip')
# sns.lmplot(data=tips, x='total_bill',y='tip')
# sns.regplot(data=tips,x='total_bill',y='tip',scatter_kws={'s':50,'color':'red',\
#                                                          'alpha':0.5})
sns.regplot(data=tips,x='total_bill',y='tip',\
            line_kws={'color':'green', 'linewidth':3,'linestyle':'--'})
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# lmplot : hue 파라미터를 이용. 데이터의 그룹을 구분, 미세한 설정을 조절할 수 있다.
sns.lmplot(data=tips, x='total_bill', y='tip', hue='smoker', markers = ['o','x'])

# sns.lmplot(data=tips, x='total_bill', y='tip', fit_reg=False)   # 회귀선을 없애서 표현

# %%
# relplot
sns.relplot(data=tips,x='total_bill',y='tip',hue='sex', style='time',size='size')

# %%
# jointplot : 각각의 변수의 분포도 보면서 두 변수 간의 상관관계도 보여줌 

sns.jointplot(data=tips, x='total_bill', y='tip', kind ='reg')


# 산점도를 그려서 이를 통과하는 회귀선, 예측식을 만든 것에서 x값을 주면 y값을 예측해주는 것.   오차의 합이 가장 낮은 것의 선임.

# %%
tdf = sns.load_dataset('titanic')
sns.heatmap(tdf[['pclass','age','fare','survived']].corr(),annot=True)

# 보통 높은 값일수록 진한 색상을 사용하고, 낮은 값일수록 연한 색상을 사용
# Out:
# <AxesSubplot:>

# %%
table = tdf.pivot_table(index=['sex'],columns=['class'],values=['survived'],aggfunc='mean')
table
# Out:
#         survived
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
plt.figure(figsize=(10,8))
sns.heatmap(table,
           annot=True,fmt='f',
           cmap = 'YlGnBu',
           linewidth=.5,
           cbar = True)
# Out:
# <AxesSubplot:xlabel='None-class', ylabel='sex'>

# %% [markdown]
# ### pairplot : 다변량 그래프로 데이터프레임에서 두변수간의 관계를 그래프로 나타냄.
# 주요 파라미터 옵션
#
# - data: 그래프를 그릴 데이터프레임
# - hue: 데이터를 구분할 컬럼명
# - vars: 그래프를 그릴 컬럼명
# - diag_kind: 대각선에 그려질 그래프의 종류 (hist, kde, ecdf)
# - kind: 그래프 종류 (scatter, reg, resid, kde, hex)
# - palette: 색상 팔레트
# - corner: 그래프의 위치 (lower, upper, both)
# - height: 그래프의 높이
# - aspect: 그래프의 가로 세로 비율
# - dropna: 결측값을 제거할지 여부

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import seaborn as sns
df_auto = pd.read_excel('../dataset/auto-mpg.xlsx')
df_auto.head()
sns.pairplot(df_auto,palette='gray')

# %%
dfa = df_auto[['mpg','weight','cylinders','displacement','origin']]
sns.pairplot(dfa,hue='origin',palette='rainbow')

# %% [markdown]
# ### 과제1.
# seaborn 그래프의 각 유형을 적용하기에 적합한 케이스를 설정해서 각 그래프를 이용해서 시각화 하세요.
#
# - relplot: 두 변수 간의 관계를 시각화하는 그래프
# - scatterplot: 산점도 그래프
# - lineplot: 선 그래프
# - histplot: 히스토그램 그래프
# - kdeplot: 밀도 그래프
# - boxplot: 박스 그래프
# - violinplot: 바이올린 그래프
# - heatmap: 히트맵 그래프
# - pairplot: 다변량 그래프

# %% [markdown]
# ### 과제2.
# 과제1의 각 경우를 matplotlib 혹은 pandas 내장함수를 이용해서 시각화 하세요.

# %% [markdown]
# ### 과제 3.
