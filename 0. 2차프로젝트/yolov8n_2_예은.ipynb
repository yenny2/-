# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
# Out:
# Ultralytics YOLOv8.0.159 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 26.3/166.8 GB disk)

# %%
# !cat '/content/drive/MyDrive/2nd_Project/Vision_Data/data.yaml'
# Out:
# names:
# - broken_line
# - circle
# - diagonal_line
# - dot
# - out_line
# - quarter_circle
# - scratch
# - semicircle
# - short_line
# - square_line
# - thick_line
# - thin_line
# nc: 12
# test: /content/drive/MyDrive/semoconductor_rfm/test
# train: /content/drive/MyDrive/2nd_Project/Vision_Data/train_mosaic
# val: /content/drive/MyDrive/semoconductor_rfm/valid

# %%
# !pip install PyYaml

# %%
import os

folder_path = "/content/drive/MyDrive/2nd_Project/Vision_Data/temp/images"
file_list = os.listdir(folder_path)
file_count = len(file_list)

print("Number of files in the folder:", file_count)
# Out:
# Number of files in the folder: 279

# %%
import os

folder_path = "/content/drive/MyDrive/semoconductor_rfm/train/labels"
file_list = os.listdir(folder_path)
file_count = len(file_list)

print("Number of files in the folder:", file_count)
# Out:
# Number of files in the folder: 2023

# %%
import os

folder_path = "/content/drive/MyDrive/semoconductor_rfm/train/images"
file_list = os.listdir(folder_path)
file_count = len(file_list)

print("Number of files in the folder:", file_count)
# Out:
# Number of files in the folder: 2023

# %%
import yaml

data = { 'train' : '/content/drive/MyDrive/2nd_Project/Vision_Data/temp/images',
         'val' : '/content/drive/MyDrive/semoconductor_rfm/valid',
         'test' : '/content/drive/MyDrive/semoconductor_rfm/test',
         'names' : ['broken_line', 'circle', 'diagonal_line', 'dot', 'out_line', 'quarter_circle', 'scratch', 'semicircle', 'short_line', 'square_line', 'thick_line', 'thin_line'],
         'nc' : 12 }


with open('/content/drive/MyDrive/2nd_Project/Vision_Data/data.yaml', 'w') as f:
    yaml.dump(data, f)

with open('/content/drive/MyDrive/2nd_Project/Vision_Data/data.yaml', 'r') as f:
    data_yaml = yaml.safe_load(f)
    display(data_yaml)
# Out:
# {'names': ['broken_line',
#   'circle',
#   'diagonal_line',
#   'dot',
#   'out_line',
#   'quarter_circle',
#   'scratch',
#   'semicircle',
#   'short_line',
#   'square_line',
#   'thick_line',
#   'thin_line'],
#  'nc': 12,
#  'test': '/content/drive/MyDrive/semoconductor_rfm/test',
#  'train': '/content/drive/MyDrive/2nd_Project/Vision_Data/temp/images',
#  'val': '/content/drive/MyDrive/semoconductor_rfm/valid'}

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')

# %%
import time
start_time = time.time()
model.train(data='/content/drive/MyDrive/2nd_Project/Vision_Data/data.yaml', epochs=100, pretrained=True, plots=True, imgsz=1200,batch=4)   # box=7.5, resume=True
end_time = time.time()
training_time_in_seconds = end_time - start_time
training_time_in_minutes = training_time_in_seconds / 60.0
print("훈련 시간: {:.2f} 분".format(training_time_in_minutes))
# Out:
# Ultralytics YOLOv8.0.159 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# test는 여기까지만

# %%
metrics = model.val(plots=True)

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/runs  # replace with 'runs' directory

# %%
results = model('/content/Semiconductor_Data/test/images', save=True)  # predict on an image

# %%
import shutil

source_dir = '/content/runs/detect/predict/'
destination_dir = '/content/drive/MyDrive/predictions2/'  # 다른 이름으로 폴더를 복사


shutil.copytree(source_dir, destination_dir)

# %%
import shutil

source_dir = '/content/runs/detect/train/'
destination_dir = '/content/drive/MyDrive/train13/'  # 다른 이름으로 폴더를 복사


shutil.copytree(source_dir, destination_dir)
